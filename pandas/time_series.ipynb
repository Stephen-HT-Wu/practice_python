# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from datetime import datetime

# %%
datetime?

# %%
datetime(year=2015, month=7,day=4)
# Out:
# datetime.datetime(2015, 7, 4, 0, 0)

# %%
from dateutil import parser

# %%
date=parser.parse("4th of July, 2015")
date
# Out:
# datetime.datetime(2015, 7, 4, 0, 0)

# %%
date.strftime?

# %%
date.strftime('%A')
# Out:
# 'Saturday'

# %%
date.strftime('%B')
# Out:
# 'July'

# %%
date.strftime('%c')
# Out:
# 'Sat Jul  4 00:00:00 2015'

# %%
pytz?
# Out:
# Object `pytz` not found.

# %%
date=np.array('2015-07-04',dtype='datetime64')
date
# Out:
# array('2015-07-04', dtype='datetime64[D]')

# %%
date+np.arange(12)
# Out:
# array(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#        '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11',
#        '2015-07-12', '2015-07-13', '2015-07-14', '2015-07-15'],
#       dtype='datetime64[D]')

# %%
np.datetime64('2015-07-04')
# Out:
# numpy.datetime64('2015-07-04')

# %%
np.datetime64('2015-07-04 12:00')
# Out:
# numpy.datetime64('2015-07-04T12:00')

# %%
np.datetime64?

# %%
np.datetime64('2015-07-04 12:00','ns')
# Out:
# numpy.datetime64('2015-07-04T12:00:00.000000000')

# %%
pd.to_datetime("4th of July, 2015")
# Out:
# Timestamp('2015-07-04 00:00:00')

# %%
date=pd.to_datetime('4th of July, 2015')

# %%
date.strftime('%A')
# Out:
# 'Saturday'

# %%
datetime.now()
# Out:
# datetime.datetime(2020, 3, 29, 15, 18, 14, 887914)

# %%
pd.to_datetime(datetime.now())
# Out:
# Timestamp('2020-03-29 15:18:54.083572')

# %%
date+pd.to_timedelta(np.arange(12),'W')
# Out:
# DatetimeIndex(['2015-07-04', '2015-07-11', '2015-07-18', '2015-07-25',
#                '2015-08-01', '2015-08-08', '2015-08-15', '2015-08-22',
#                '2015-08-29', '2015-09-05', '2015-09-12', '2015-09-19'],
#               dtype='datetime64[ns]', freq=None)

# %%
index=pd.DatetimeIndex(['2014-07-04','2014-08-04','2015-07-05','2015-08-04'])

# %%
index
# Out:
# DatetimeIndex(['2014-07-04', '2014-08-04', '2015-07-05', '2015-08-04'], dtype='datetime64[ns]', freq=None)

# %%
data=pd.Series([0,1,2,3],index=index)
data
# Out:
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-05    2
# 2015-08-04    3
# dtype: int64

# %%
plt.scatter(data.index,data)

# %%
data['2014-07-04':'2015-07-04']
# Out:
# 2014-07-04    0
# 2014-08-04    1
# dtype: int64

# %%
data.loc['2014-07-04':'2015-07-05']
# Out:
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-05    2
# dtype: int64

# %%
data['2015']
# Out:
# 2015-07-05    2
# 2015-08-04    3
# dtype: int64

# %%
pd.to_datetime('2020')
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
pd.to_datetime(['2020','2019'])
# Out:
# DatetimeIndex(['2020-01-01', '2019-01-01'], dtype='datetime64[ns]', freq=None)

# %%
dates=pd.to_datetime([datetime(2015,7,3),'4th of july 2015','2015-jul-6','07-07-2015','20150708'])

# %%
dates
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-06', '2015-07-07',
#                '2015-07-08'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates.to_period('M')
# Out:
# PeriodIndex(['2015-07', '2015-07', '2015-07', '2015-07', '2015-07'], dtype='period[M]', freq='M')

# %%
dates-dates[0]
# Out:
# TimedeltaIndex(['0 days', '1 days', '3 days', '4 days', '5 days'], dtype='timedelta64[ns]', freq=None)

# %%
dates
# Out:
# Timestamp('2015-07-03 00:00:00')

# %%
pd.date_range('20150704','20150708')
# Out:
# DatetimeIndex(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#                '2015-07-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('20150704',periods=8)
# Out:
# DatetimeIndex(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#                '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('20150704',periods=8,freq='H')
# Out:
# DatetimeIndex(['2015-07-04 00:00:00', '2015-07-04 01:00:00',
#                '2015-07-04 02:00:00', '2015-07-04 03:00:00',
#                '2015-07-04 04:00:00', '2015-07-04 05:00:00',
#                '2015-07-04 06:00:00', '2015-07-04 07:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
pd.date_range('20150704',periods=8,freq='M')
# Out:
# DatetimeIndex(['2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31',
#                '2015-11-30', '2015-12-31', '2016-01-31', '2016-02-29'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.timedelta_range('20150704',periods=8,freq='2D')
# Out:
# TimedeltaIndex([ '0 days 00:00:00.020150',  '2 days 00:00:00.020150',
#                  '4 days 00:00:00.020150',  '6 days 00:00:00.020150',
#                  '8 days 00:00:00.020150', '10 days 00:00:00.020150',
#                 '12 days 00:00:00.020150', '14 days 00:00:00.020150'],
#                dtype='timedelta64[ns]', freq='2D')

# %%
pd.timedelta_range(0,periods=8,freq='2H')
# Out:
# TimedeltaIndex(['00:00:00', '02:00:00', '04:00:00', '06:00:00', '08:00:00',
#                 '10:00:00', '12:00:00', '14:00:00'],
#                dtype='timedelta64[ns]', freq='2H')

# %%
print(pd.date_range('20150704',periods=4,freq='H'))
print(pd.date_range('20150704',periods=4,freq='W'))
print(pd.date_range('20150704',periods=4,freq='M'))
print(pd.date_range('20150704',periods=4,freq='MS'))
print(pd.date_range('20150704',periods=4,freq='Y'))
print(pd.date_range('20150704',periods=4,freq='Q'))
# Out:
# DatetimeIndex(['2015-07-04 00:00:00', '2015-07-04 01:00:00',
#                '2015-07-04 02:00:00', '2015-07-04 03:00:00'],
#               dtype='datetime64[ns]', freq='H')
# DatetimeIndex(['2015-07-05', '2015-07-12', '2015-07-19', '2015-07-26'], dtype='datetime64[ns]', freq='W-SUN')
# DatetimeIndex(['2015-07-31', '2015-08-31', '2015-09-30', '2015-10-31'], dtype='datetime64[ns]', freq='M')
# DatetimeIndex(['2015-08-01', '2015-09-01', '2015-10-01', '2015-11-01'], dtype='datetime64[ns]', freq='MS')
# DatetimeIndex(['2015-12-31', '2016-12-31', '2017-12-31', '2018-12-31'], dtype='datetime64[ns]', freq='A-DEC')
# DatetimeIndex(['2015-09-30', '2015-12-31', '2016-03-31', '2016-06-30'], dtype='datetime64[ns]', freq='Q-DEC')

# %%
print(pd.date_range('20150704',periods=8,freq='B'))
# Out:
# DatetimeIndex(['2015-07-06', '2015-07-07', '2015-07-08', '2015-07-09',
#                '2015-07-10', '2015-07-13', '2015-07-14', '2015-07-15'],
#               dtype='datetime64[ns]', freq='B')

# %%
print(pd.date_range('20150704',periods=8,freq='BM'))
# Out:
# DatetimeIndex(['2015-07-31', '2015-08-31', '2015-09-30', '2015-10-30',
#                '2015-11-30', '2015-12-31', '2016-01-29', '2016-02-29'],
#               dtype='datetime64[ns]', freq='BM')

# %%
print(pd.date_range('20150704',periods=8,freq='T')) #minutes
print(pd.date_range('20150704',periods=8,freq='L')) #millisecond
print(pd.date_range('20150704',periods=8,freq='U')) #microsecond
print(pd.date_range('20150704',periods=8,freq='N')) #nanosecond
# Out:
# DatetimeIndex(['2015-07-04 00:00:00', '2015-07-04 00:01:00',
#                '2015-07-04 00:02:00', '2015-07-04 00:03:00',
#                '2015-07-04 00:04:00', '2015-07-04 00:05:00',
#                '2015-07-04 00:06:00', '2015-07-04 00:07:00'],
#               dtype='datetime64[ns]', freq='T')
# DatetimeIndex([       '2015-07-04 00:00:00', '2015-07-04 00:00:00.001000',
#                '2015-07-04 00:00:00.002000', '2015-07-04 00:00:00.003000',
#                '2015-07-04 00:00:00.004000', '2015-07-04 00:00:00.005000',
#                '2015-07-04 00:00:00.006000', '2015-07-04 00:00:00.007000'],
#               dtype='datetime64[ns]', freq='L')
# DatetimeIndex([       '2015-07-04 00:00:00', '2015-07-04 00:00:00.000001',
#                '2015-07-04 00:00:00.000002', '2015-07-04 00:00:00.000003',
#                '2015-07-04 00:00:00.000004', '2015-07-04 00:00:00.000005',
#                '2015-07-04 00:00:00.000006', '2015-07-04 00:00:00.000007'],
# ...

# %%
print(pd.date_range('20150704',periods=4,freq='Q'))
print(pd.date_range('20150704',periods=4,freq='Q-JAN'))
print(pd.date_range('20150704',periods=4,freq='Q-FEB'))
# Out:
# DatetimeIndex(['2015-09-30', '2015-12-31', '2016-03-31', '2016-06-30'], dtype='datetime64[ns]', freq='Q-DEC')
# DatetimeIndex(['2015-07-31', '2015-10-31', '2016-01-31', '2016-04-30'], dtype='datetime64[ns]', freq='Q-JAN')
# DatetimeIndex(['2015-08-31', '2015-11-30', '2016-02-29', '2016-05-31'], dtype='datetime64[ns]', freq='Q-FEB')

# %%
print(pd.date_range('20150704',periods=4,freq='W'))
print(pd.date_range('20150704',periods=4,freq='W-SUN'))
print(pd.date_range('20150704',periods=4,freq='W-WED'))
# Out:
# DatetimeIndex(['2015-07-05', '2015-07-12', '2015-07-19', '2015-07-26'], dtype='datetime64[ns]', freq='W-SUN')
# DatetimeIndex(['2015-07-05', '2015-07-12', '2015-07-19', '2015-07-26'], dtype='datetime64[ns]', freq='W-SUN')
# DatetimeIndex(['2015-07-08', '2015-07-15', '2015-07-22', '2015-07-29'], dtype='datetime64[ns]', freq='W-WED')

# %%
print(pd.date_range('20150704',periods=4,freq='3H40T'))
# Out:
# DatetimeIndex(['2015-07-04 00:00:00', '2015-07-04 03:40:00',
#                '2015-07-04 07:20:00', '2015-07-04 11:00:00'],
#               dtype='datetime64[ns]', freq='220T')

# %%
from pandas_datareader import data
# Out:
# /home/stephen/anaconda3/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
yahoo=data.DataReader('GOOG',start='2004',end='2016',data_source='yahoo')
yahoo.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2004-08-19  51.835709  47.800831  49.813286  49.982655  44871300.0  49.982655
# 2004-08-20  54.336334  50.062355  50.316402  53.952770  22942800.0  53.952770
# 2004-08-23  56.528118  54.321388  55.168217  54.495735  18342800.0  54.495735
# 2004-08-24  55.591629  51.591621  55.412300  52.239193  15319700.0  52.239193
# 2004-08-25  53.798351  51.746044  52.284027  52.802086   9232100.0  52.802086

# %%
close=yahoo['Close']

# %%
sns.set()

# %%
plt.plot(close)

# %%
close.plot()

# %%
type(close)
# Out:
# pandas.core.series.Series

# %%
close.resample?

# %%
close.plot(alpha=0.5,style='-')
close.resample('BA').mean().plot(style=':')
close.asfreq('BA').plot(style='--')
plt.legend(['input','resample','asfreq'],loc='upper left')

# %%
plt.subplot?

# %%
fig,ax = plt.subplots(2,sharex=True)
data=close.iloc[:10]
data.asfreq('D').plot(ax=ax[0],marker='o')
data.asfreq('D',method='bfill').plot(ax=ax[1],style='-o')
data.asfreq('D',method='ffill').plot(ax=ax[1],style='--o')
ax[1].legend(['back-fill','forward-fill'])

# %%
fig,ax = plt.subplots(2,sharex=True)
data=close.iloc[:10]
data.asfreq('D').plot(ax=ax[0],marker='o')
data.asfreq('D',method='bfill').plot(ax=ax[1],style='-o')
data.asfreq('D',method='ffill').plot(ax=ax[1],style='--o')
#ax[1].legend(['back-fill','forward-fill'])

# %%
data.asfreq('D').plot(marker='o')
data.asfreq('D',method='bfill').plot(linestyle=':')
data.asfreq('D',method='ffill').plot(style='-.')

# %%
close.asfreq?

# %%
fig,ax=plt.subplots(3,sharey=True)
x=close.asfreq('D',method='pad')
x.plot(ax=ax[0])
x.shift(900).plot(ax=ax[1])
x.tshift(900).plot(ax=ax[2])
local_max=pd.to_datetime('2007-11-05')
offset=pd.Timedelta(900,'D')

ax[0].legend(['input'],loc=2)
ax[0].get_xticklabels()[4].set(weight='heavy',color='red')
ax[0].axvline(local_max,alpha=0.3,color='red')

ax[1].legend(['shift 900'],loc=2)
ax[1].get_xticklabels()[4].set(weight='heavy',color='red')
ax[1].axvline(local_max+offset,alpha=0.3,color='red')

ax[2].legend(['tshift(900)'],loc=2)
ax[2].get_xticklabels()[1].set(weight='heavy',color='red')
ax[2].axvline(local_max+offset,alpha=0.3,color='red')

# %%
x.tshift?

# %%
close.plot()

# %%
x=close.asfreq('D',method='pad')
x.tshift(-365)
# Out:
# Date
# 2003-08-20     49.982655
# 2003-08-21     53.952770
# 2003-08-22     53.952770
# 2003-08-23     53.952770
# 2003-08-24     54.495735
#                  ...
# 2014-12-27    748.400024
# 2014-12-28    762.510010
# 2014-12-29    776.599976
# 2014-12-30    771.000000
# 2014-12-31    758.880005
# Freq: D, Name: Close, Length: 4152, dtype: float64

# %%
x.head()
# Out:
# Date
# 2004-08-19    49.982655
# 2004-08-20    53.952770
# 2004-08-21    53.952770
# 2004-08-22    53.952770
# 2004-08-23    54.495735
# Freq: D, Name: Close, dtype: float64

# %%
ROI=100*(x.tshift(-365)/x-1)
ROI.plot()
plt.ylabel('% Return on Investment')
# Out:
# Text(0, 0.5, '% Return on Investment')

# %%
plt.plot(100*(x.tshift(-365)/x-1))
plt.plot(100*(x.shift(-365)/x-1),linestyle=':')
plt.legend(['a','b'])
plt.ylabel('% Return on Investment')
# Out:
# Text(0, 0.5, '% Return on Investment')

# %%
x.rolling?

# %%
rolling=x.rolling(365,center=True)

# %%
w=pd.DataFrame({'input':x,
               'rolling mean':rolling.mean(),
               'rolling std':rolling.std()})
ax=w.plot(style=['-','--',':'])
ax.lines[0].set_alpha(0.3)
