# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('seaborn-white')

# %%
def f(x,y):
    return np.sin(x)**10+np.cos(10+y*x)*np.cos(x)

# %%
np.meshgrid?

# %%
np.linspace?

# %%
plt.plot(np.linspace(1,10,50),label='line')
plt.plot(np.geomspace(1,10,50),label='geom')
#plt.plot(np.logspace(1,10,50),label='log')
plt.legend()

# %%
plt.scatter(range(10),np.logspace(1,11,10),label='log')
plt.yscale('log')

# %%
np.geomspace?

# %%
x=np.linspace(0,5,50)
y=np.linspace(0,5,40)
X,Y=np.meshgrid(x,y)

# %%
X.shape
# Out:
# (40, 50)

# %%
Y.shape
# Out:
# (40, 50)

# %%
x.shape
# Out:
# (50,)

# %%
x
# Out:
# array([0.        , 0.10204082, 0.20408163, 0.30612245, 0.40816327,
#        0.51020408, 0.6122449 , 0.71428571, 0.81632653, 0.91836735,
#        1.02040816, 1.12244898, 1.2244898 , 1.32653061, 1.42857143,
#        1.53061224, 1.63265306, 1.73469388, 1.83673469, 1.93877551,
#        2.04081633, 2.14285714, 2.24489796, 2.34693878, 2.44897959,
#        2.55102041, 2.65306122, 2.75510204, 2.85714286, 2.95918367,
#        3.06122449, 3.16326531, 3.26530612, 3.36734694, 3.46938776,
#        3.57142857, 3.67346939, 3.7755102 , 3.87755102, 3.97959184,
#        4.08163265, 4.18367347, 4.28571429, 4.3877551 , 4.48979592,
#        4.59183673, 4.69387755, 4.79591837, 4.89795918, 5.        ])

# %%
X[:10,1]
# Out:
# array([0.10204082, 0.10204082, 0.10204082, 0.10204082, 0.10204082,
#        0.10204082, 0.10204082, 0.10204082, 0.10204082, 0.10204082])

# %%
Y[:10,1]
# Out:
# array([0.        , 0.12820513, 0.25641026, 0.38461538, 0.51282051,
#        0.64102564, 0.76923077, 0.8974359 , 1.02564103, 1.15384615])

# %%
 Z=f(X,Y)

# %%
Z.shape
# Out:
# (40, 50)

# %%
plt.contour(X,Y,Z,colors='black')

# %%
plt.contour(X,Y,Z,cmap='viridis')

# %%
plt.contour(X,Y,Z,20,cmap='viridis')
plt.colorbar()

# %%
plt.contour(X,Y,Z,20,cmap='RdGy')
plt.colorbar()

# %%
plt.cm?

# %%
plt.contourf(X,Y,Z,20,cmap='RdGy')
plt.colorbar()

# %%
plt.imshow(Z,extent=[0,5,0,5],origin='lower',cmap='RdGy') #extent=[xmin,xmax,ymin,ymax]
plt.colorbar()
plt.axis('image')
# Out:
# (0.0, 5.0, 0.0, 5.0)

# %%
plt.imshow(Z,extent=[0,5,0,5],cmap='RdGy') #extent=[xmin,xmax,ymin,ymax]
plt.colorbar()

# %%
contours=plt.contour(X,Y,Z,3,colors='black')
plt.clabel(contours,inline=True,fontsize=8)
plt.imshow(Z,extent=[0,5,0,5],origin='lower',cmap='RdGy',alpha=0.5) #extent=[xmin,xmax,ymin,ymax]
plt.colorbar()

# %%
plt.clabel?

# %%
a=np.linspace(0,10,40)
b=np.linspace(0,10,40)
A,B=np.meshgrid(a,b)
def g(x,y):
    return np.sin(x**2)+np.cos(y**3)
C=g(A,B)

# %%
plt.contourf(A,B,C,cmap='viridis')
plt.colorbar()
